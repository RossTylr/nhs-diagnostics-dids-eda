# %%
# ---
# Notebook: 02_review_ct_mri_procedures.ipynb
# Purpose: Review top 50 procedures containing CT and MRI variants
# ---

import pandas as pd

# --- Load summary CSV ---
df = pd.read_csv("../data/processed/snomed_procedure_summary.csv")
df.columns = df.columns.str.strip()
df['SNOMED Procedure'] = df['SNOMED Procedure'].astype(str).str.strip()

# --- Define CT and MRI keyword patterns ---
ct_keywords = [
    "CT", "Ct", "ct", 
    "Computed Tomography", "computed tomography", 
    "CT scan", "ct scan"
]

mri_keywords = [
    "MRI", "Mri", "mri", 
    "Magnetic Resonance Imaging", "magnetic resonance imaging", 
    "MR scan", "MR ", "Mr scan"
]

# --- Filter function ---
def filter_top_procedures(df, keywords, label, top_n=50):
    pattern = "|".join([fr"\b{kw}\b" for kw in keywords])
    filtered_df = df[df['SNOMED Procedure'].str.contains(pattern, case=False, regex=True)].copy()
    filtered_df = filtered_df.sort_values(by='Count', ascending=False).head(top_n).reset_index(drop=True)
    
    print(f"\n🔍 Top {top_n} procedures for: {label}")
    display(
        filtered_df.style
        .set_caption(f"Top {top_n} {label} Procedures (by Count)")
        .format({"Count": "{:,.0f}", "% of Total": "{:.2f}%"})
        .background_gradient(subset='Count', cmap='Greens')
        .set_table_styles([
            {"selector": "caption", "props": [("caption-side", "top"), ("font-weight", "bold")]}
        ])
    )

# --- Display CT and MRI results ---
filter_top_procedures(df, ct_keywords, "CT")
filter_top_procedures(df, mri_keywords, "MRI")
# Out:
# 🔍 Top 50 procedures for: CT
# <style type="text/css">
# #T_65d9f caption {
#   caption-side: top;
#   font-weight: bold;
# }
# #T_65d9f_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_65d9f_row1_col1 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_65d9f_row2_col1 {
#   background-color: #75c477;
#   color: #000000;
# }
# #T_65d9f_row3_col1 {
#   background-color: #abdda5;
#   color: #000000;
# }
# #T_65d9f_row4_col1 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_65d9f_row5_col1 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_65d9f_row6_col1, #T_65d9f_row7_col1 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_65d9f_row8_col1 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_65d9f_row9_col1, #T_65d9f_row10_col1 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_65d9f_row11_col1, #T_65d9f_row12_col1, #T_65d9f_row13_col1, #T_65d9f_row14_col1 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_65d9f_row15_col1 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_65d9f_row16_col1 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_65d9f_row17_col1 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_65d9f_row18_col1 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_65d9f_row19_col1, #T_65d9f_row20_col1, #T_65d9f_row21_col1, #T_65d9f_row22_col1, #T_65d9f_row23_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_65d9f_row24_col1, #T_65d9f_row25_col1, #T_65d9f_row26_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_65d9f_row27_col1, #T_65d9f_row28_col1, #T_65d9f_row29_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_65d9f_row30_col1, #T_65d9f_row31_col1, #T_65d9f_row32_col1, #T_65d9f_row33_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_65d9f_row34_col1, #T_65d9f_row35_col1, #T_65d9f_row36_col1, #T_65d9f_row37_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_65d9f_row38_col1, #T_65d9f_row39_col1, #T_65d9f_row40_col1, #T_65d9f_row41_col1, #T_65d9f_row42_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_65d9f_row43_col1, #T_65d9f_row44_col1, #T_65d9f_row45_col1, #T_65d9f_row46_col1, #T_65d9f_row47_col1, #T_65d9f_row48_col1, #T_65d9f_row49_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_65d9f">
#   <caption>Top 50 CT Procedures (by Count)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65d9f_level0_col0" class="col_heading level0 col0" >SNOMED Procedure</th>
#       <th id="T_65d9f_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_65d9f_level0_col2" class="col_heading level0 col2" >% of Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65d9f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_65d9f_row0_col0" class="data row0 col0" >Computed tomography of entire head (procedure)</td>
#       <td id="T_65d9f_row0_col1" class="data row0 col1" >9,281</td>
#       <td id="T_65d9f_row0_col2" class="data row0 col2" >2.53%</td>
#     </tr>
#     <tr>
#       <th id="T_65d9f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_65d9f_row1_col0" class="data row1 col0" >Computed tomography of entire head (procedure) (408754009)</td>
#       <td id="T_65d9f_row1_col1" class="data row1 col1" >5,410</td>
#       <td id="T_65d9f_row1_col2" class="data row1 col2" >1.48%</td>
#     </tr>
#     <tr>
#       <th id="T_65d9f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_65d9f_row2_col0" class="data row2 col0" >Computed tomography of thorax, abdomen and pelvis with contrast (procedure)</td>
#       <td id="T_65d9f_row2_col1" class="data row2 col1" >4,687</td>
#       <td id="T_65d9f_row2_col2" class="data row2 col2" >1.28%</td>
#     </tr>
#     <tr>
#       <th id="T_65d9f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_65d9f_row3_col0" class="data row3 col0" >Computed tomography of abdomen and pelvis with contrast (procedure)</td>
#       <td id="T_65d9f_row3_col1" class="data row3 col1" >3,271</td>
#       <td id="T_65d9f_row3_col2" class="data row3 col2" >0.89%</td>
#     </tr>
#     <tr>
#       <th id="T_65d9f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_65d9f_row4_col0" class="data row4 col0" >Computed tomography of thorax, abdomen and pelvis with contrast (procedure) (433761009)</td>
#       <td id="T_65d9f_row4_col1" class="data row4 col1" >2,705</td>
#       <td id="T_65d9f_row4_col2" class="data row4 col2" >0.74%</td>
#     </tr>
#     <tr>
#       <th id="T_65d9f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_65d9f_row5_col0" class="data row5 col0" >Computed tomography of abdomen and pelvis with contrast (procedure) (432370003)</td>
#       <td id="T_65d9f_row5_col1" class="data row5 col1" >2,354</td>
#       <td id="T_65d9f_row5_col2" class="data row5 col2" >0.64%</td>
#     </tr>
#     <tr>
#       <th id="T_65d9f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_65d9f_row6_col0" class="data row6 col0" >Computed tomography of chest (procedure)</td>
#       <td id="T_65d9f_row6_col1" class="data row6 col1" >2,050</td>
#       <td id="T_65d9f_row6_col2" class="data row6 col2" >0.56%</td>
#     </tr>
#     <tr>
#       <th id="T_65d9f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_65d9f_row7_col0" class="data row7 col0" >Computed tomography angiography of pulmonary artery with contrast (procedure)</td>
#       <td id="T_65d9f_row7_col1" class="data row7 col1" >2,042</td>
#       <td id="T_65d9f_row7_col2" class="data row7 col2" >0.56%</td>
#     </tr>
#     <tr>
#       <th id="T_65d9f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_65d9f_row8_col0" class="data row8 col0" >Positron emission tomography with computed tomography fluorodeoxyglucose imaging of whole body (procedure) (443271005)</td>
#       <td id="T_65d9f_row8_col1" class="data row8 col1" >1,554</td>
#       <td id="T_65d9f_row8_col2" class="data row8 col2" >0.42%</td>
#     </tr>
#     <tr>
#       <th id="T_65d9f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_65d9f_row9_col0" class="data row9 col0" >Computed tomography of chest (procedure) (169069000)</td>
#       <td id="T_65d9f_row9_col1" class="data row9 col1" >1,139</td>
#       <td id="T_65d9f_row9_col2" class="data row9 col2" >0.31%</td>
#     </tr>
#     <tr>
#       <th id="T_65d9f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_65d9f_row10_col0" class="data row10 col0" >Computed tomography of chest, abdomen and pelvis (procedure)</td>
#       <td id="T_65d9f_row10_col1" class="data row10 col1" >1,122</td>
#       <td id="T_65d9f_row10_col2" class="data row10 col2" >0.31%</td>
#     </tr>
#     <tr>
#       <th id="T_65d9f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_65d9f_row11_col0" class="data row11 col0" >Computed tomography of abdomen and pelvis (procedure)</td>
#       <td id="T_65d9f_row11_col1" class="data row11 col1" >1,055</td>
#       <td id="T_65d9f_row11_col2" class="data row11 col2" >0.29%</td>
#     </tr>
#     <tr>
#       <th id="T_65d9f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_65d9f_row12_col0" class="data row12 col0" >Low dose computed tomography of thorax (procedure)</td>
#       <td id="T_65d9f_row12_col1" class="data row12 col1" >1,018</td>
#       <td id="T_65d9f_row12_col2" class="data row12 col2" >0.28%</td>
#     </tr>
#     <tr>
#       <th id="T_65d9f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_65d9f_row13_col0" class="data row13 col0" >Computed tomography angiography of coronary arteries (procedure)</td>
#       <td id="T_65d9f_row13_col1" class="data row13 col1" >1,014</td>
#       <td id="T_65d9f_row13_col2" class="data row13 col2" >0.28%</td>
#     </tr>
#     <tr>
#       <th id="T_65d9f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_65d9f_row14_col0" class="data row14 col0" >Computed tomography of cervical spine (procedure)</td>
#       <td id="T_65d9f_row14_col1" class="data row14 col1" >1,008</td>
#       <td id="T_65d9f_row14_col2" class="data row14 col2"
# 🔍 Top 50 procedures for: MRI
# <style type="text/css">
# #T_a544e caption {
#   caption-side: top;
#   font-weight: bold;
# }
# #T_a544e_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_a544e_row1_col1 {
#   background-color: #5ab769;
#   color: #f1f1f1;
# }
# #T_a544e_row2_col1 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_a544e_row3_col1 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_a544e_row4_col1 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_a544e_row5_col1, #T_a544e_row6_col1 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_a544e_row7_col1 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_a544e_row8_col1 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_a544e_row9_col1 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_a544e_row10_col1, #T_a544e_row11_col1 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_a544e_row12_col1 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_a544e_row13_col1 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_a544e_row14_col1 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_a544e_row15_col1 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_a544e_row16_col1, #T_a544e_row17_col1 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_a544e_row18_col1 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_a544e_row19_col1 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_a544e_row20_col1, #T_a544e_row21_col1, #T_a544e_row22_col1, #T_a544e_row23_col1 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_a544e_row24_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_a544e_row25_col1 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_a544e_row26_col1, #T_a544e_row27_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_a544e_row28_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_a544e_row29_col1, #T_a544e_row30_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_a544e_row31_col1, #T_a544e_row32_col1, #T_a544e_row33_col1, #T_a544e_row34_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_a544e_row35_col1, #T_a544e_row36_col1, #T_a544e_row37_col1, #T_a544e_row38_col1, #T_a544e_row39_col1, #T_a544e_row40_col1, #T_a544e_row41_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_a544e_row42_col1, #T_a544e_row43_col1, #T_a544e_row44_col1, #T_a544e_row45_col1, #T_a544e_row46_col1, #T_a544e_row47_col1, #T_a544e_row48_col1, #T_a544e_row49_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_a544e">
#   <caption>Top 50 MRI Procedures (by Count)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a544e_level0_col0" class="col_heading level0 col0" >SNOMED Procedure</th>
#       <th id="T_a544e_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_a544e_level0_col2" class="col_heading level0 col2" >% of Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a544e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a544e_row0_col0" class="data row0 col0" >Magnetic resonance imaging of head (procedure)</td>
#       <td id="T_a544e_row0_col1" class="data row0 col1" >3,377</td>
#       <td id="T_a544e_row0_col2" class="data row0 col2" >0.92%</td>
#     </tr>
#     <tr>
#       <th id="T_a544e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a544e_row1_col0" class="data row1 col0" >Magnetic resonance imaging of head (procedure) (241601008)</td>
#       <td id="T_a544e_row1_col1" class="data row1 col1" >1,954</td>
#       <td id="T_a544e_row1_col2" class="data row1 col2" >0.53%</td>
#     </tr>
#     <tr>
#       <th id="T_a544e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a544e_row2_col0" class="data row2 col0" >Magnetic resonance imaging of lumbar and sacral spine (procedure)</td>
#       <td id="T_a544e_row2_col1" class="data row2 col1" >1,550</td>
#       <td id="T_a544e_row2_col2" class="data row2 col2" >0.42%</td>
#     </tr>
#     <tr>
#       <th id="T_a544e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a544e_row3_col0" class="data row3 col0" >Magnetic resonance imaging of lumbar and sacral spine (procedure) (433141005)</td>
#       <td id="T_a544e_row3_col1" class="data row3 col1" >1,443</td>
#       <td id="T_a544e_row3_col2" class="data row3 col2" >0.39%</td>
#     </tr>
#     <tr>
#       <th id="T_a544e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a544e_row4_col0" class="data row4 col0" >Magnetic resonance imaging of head with contrast (procedure) (432874000)</td>
#       <td id="T_a544e_row4_col1" class="data row4 col1" >845</td>
#       <td id="T_a544e_row4_col2" class="data row4 col2" >0.23%</td>
#     </tr>
#     <tr>
#       <th id="T_a544e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a544e_row5_col0" class="data row5 col0" >Magnetic resonance imaging of head with contrast (procedure)</td>
#       <td id="T_a544e_row5_col1" class="data row5 col1" >817</td>
#       <td id="T_a544e_row5_col2" class="data row5 col2" >0.22%</td>
#     </tr>
#     <tr>
#       <th id="T_a544e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a544e_row6_col0" class="data row6 col0" >Magnetic resonance imaging of spine (procedure)</td>
#       <td id="T_a544e_row6_col1" class="data row6 col1" >810</td>
#       <td id="T_a544e_row6_col2" class="data row6 col2" >0.22%</td>
#     </tr>
#     <tr>
#       <th id="T_a544e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a544e_row7_col0" class="data row7 col0" >Magnetic resonance imaging of cervical spine (procedure)</td>
#       <td id="T_a544e_row7_col1" class="data row7 col1" >805</td>
#       <td id="T_a544e_row7_col2" class="data row7 col2" >0.22%</td>
#     </tr>
#     <tr>
#       <th id="T_a544e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a544e_row8_col0" class="data row8 col0" >Magnetic resonance imaging of cervical spine (procedure) (241646009)</td>
#       <td id="T_a544e_row8_col1" class="data row8 col1" >683</td>
#       <td id="T_a544e_row8_col2" class="data row8 col2" >0.19%</td>
#     </tr>
#     <tr>
#       <th id="T_a544e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a544e_row9_col0" class="data row9 col0" >Magnetic resonance imaging of internal auditory meatus (procedure)</td>
#       <td id="T_a544e_row9_col1" class="data row9 col1" >557</td>
#       <td id="T_a544e_row9_col2" class="data row9 col2" >0.15%</td>
#     </tr>
#     <tr>
#       <th id="T_a544e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a544e_row10_col0" class="data row10 col0" >Magnetic resonance imaging of internal auditory meatus (procedure) (241606003)</td>
#       <td id="T_a544e_row10_col1" class="data row10 col1" >537</td>
#       <td id="T_a544e_row10_col2" class="data row10 col2" >0.15%</td>
#     </tr>
#     <tr>
#       <th id="T_a544e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a544e_row11_col0" class="data row11 col0" >Magnetic resonance imaging of spine (procedure) (241645008)</td>
#       <td id="T_a544e_row11_col1" class="data row11 col1" >536</td>
#       <td id="T_a544e_row11_col2" class="data row11 col2" >0.15%</td>
#     </tr>
#     <tr>
#       <th id="T_a544e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a544e_row12_col0" class="data row12 col0" >Magnetic resonance imaging of right knee (procedure)</td>
#       <td id="T_a544e_row12_col1" class="data row12 col1" >512</td>
#       <td id="T_a544e_row12_col2" class="data row12 col2" >0.14%</td>
#     </tr>
#     <tr>
#       <th id="T_a544e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a544e_row13_col0" class="data row13 col0" >Magnetic resonance imaging of prostate (procedure)</td>
#       <td id="T_a544e_row13_col1" class="data row13 col1" >492</td>
#       <td id="T_a544e_row13_col2" class="data row13 col2" >0.13%</td>
#     </tr>
#     <tr>
#       <th id="T_a544e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a544e_row14_col0" class="data row14 col0" >Magnetic resonance imagi

# %%
import re, pandas as pd

df = pd.read_csv("../data/processed/snomed_procedure_summary.csv")

# Step A – clean duplicates
df['proc_clean'] = (
    df['SNOMED Procedure']
    .str.replace(r"\s*\(\d+\)$", "", regex=True)
    .str.strip()
    .str.lower()
)

# Step B – CT filter without PET/SPECT/CBCT
ct_pattern   = r"\b(ct|computed tomography)\b"
ct_excl      = r"(pet|positron emission|single photon|cone beam)"
df_ct        = df[df['proc_clean'].str.contains(ct_pattern) &
                  ~df['proc_clean'].str.contains(ct_excl)]

# Step C – MRI filter
mri_pattern  = r"\b(mri|magnetic resonance)\b"
df_mri       = df[df['proc_clean'].str.contains(mri_pattern)]

# Step D – collapse duplicates and show head-only tables
for label, sub in [("CT", df_ct), ("MRI", df_mri)]:
    sub2 = (sub.groupby('proc_clean', as_index=False)
                 .agg({'Count':'sum', '% of Total':'sum'})
                 .sort_values('Count', ascending=False)
                 .head(50))
    display(sub2.style.set_caption(f"Top 50 {label} (de-duplicated)"))
# Out:
# /var/folders/sy/gz5gl6d91cbfwd2z85r62rbc0000gn/T/ipykernel_8450/3644593463.py:16: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_ct        = df[df['proc_clean'].str.contains(ct_pattern) &
# /var/folders/sy/gz5gl6d91cbfwd2z85r62rbc0000gn/T/ipykernel_8450/3644593463.py:17: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   ~df['proc_clean'].str.contains(ct_excl)]
# /var/folders/sy/gz5gl6d91cbfwd2z85r62rbc0000gn/T/ipykernel_8450/3644593463.py:21: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_mri       = df[df['proc_clean'].str.contains(mri_pattern)]
# <style type="text/css">
# </style>
# <table id="T_7f8d5">
#   <caption>Top 50 CT (de-duplicated)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f8d5_level0_col0" class="col_heading level0 col0" >proc_clean</th>
#       <th id="T_7f8d5_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_7f8d5_level0_col2" class="col_heading level0 col2" >% of Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f8d5_level0_row0" class="row_heading level0 row0" >64</th>
#       <td id="T_7f8d5_row0_col0" class="data row0 col0" >computed tomography of entire head (procedure)</td>
#       <td id="T_7f8d5_row0_col1" class="data row0 col1" >14691</td>
#       <td id="T_7f8d5_row0_col2" class="data row0 col2" >4.010000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row1" class="row_heading level0 row1" >167</th>
#       <td id="T_7f8d5_row1_col0" class="data row1 col0" >computed tomography of thorax, abdomen and pelvis with contrast (procedure)</td>
#       <td id="T_7f8d5_row1_col1" class="data row1 col1" >7392</td>
#       <td id="T_7f8d5_row1_col2" class="data row1 col2" >2.020000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row2" class="row_heading level0 row2" >42</th>
#       <td id="T_7f8d5_row2_col0" class="data row2 col0" >computed tomography of abdomen and pelvis with contrast (procedure)</td>
#       <td id="T_7f8d5_row2_col1" class="data row2 col1" >5625</td>
#       <td id="T_7f8d5_row2_col2" class="data row2 col2" >1.530000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row3" class="row_heading level0 row3" >57</th>
#       <td id="T_7f8d5_row3_col0" class="data row3 col0" >computed tomography of chest (procedure)</td>
#       <td id="T_7f8d5_row3_col1" class="data row3 col1" >3189</td>
#       <td id="T_7f8d5_row3_col2" class="data row3 col2" >0.870000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row4" class="row_heading level0 row4" >24</th>
#       <td id="T_7f8d5_row4_col0" class="data row4 col0" >computed tomography angiography of pulmonary artery with contrast (procedure)</td>
#       <td id="T_7f8d5_row4_col1" class="data row4 col1" >2324</td>
#       <td id="T_7f8d5_row4_col2" class="data row4 col2" >0.640000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row5" class="row_heading level0 row5" >16</th>
#       <td id="T_7f8d5_row5_col0" class="data row5 col0" >computed tomography angiography of coronary arteries (procedure)</td>
#       <td id="T_7f8d5_row5_col1" class="data row5 col1" >1541</td>
#       <td id="T_7f8d5_row5_col2" class="data row5 col2" >0.420000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row6" class="row_heading level0 row6" >56</th>
#       <td id="T_7f8d5_row6_col0" class="data row6 col0" >computed tomography of cervical spine (procedure)</td>
#       <td id="T_7f8d5_row6_col1" class="data row6 col1" >1539</td>
#       <td id="T_7f8d5_row6_col2" class="data row6 col2" >0.410000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row7" class="row_heading level0 row7" >165</th>
#       <td id="T_7f8d5_row7_col0" class="data row7 col0" >computed tomography of thorax with contrast (procedure)</td>
#       <td id="T_7f8d5_row7_col1" class="data row7 col1" >1342</td>
#       <td id="T_7f8d5_row7_col2" class="data row7 col2" >0.360000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row8" class="row_heading level0 row8" >204</th>
#       <td id="T_7f8d5_row8_col0" class="data row8 col0" >low dose computed tomography of thorax (procedure)</td>
#       <td id="T_7f8d5_row8_col1" class="data row8 col1" >1315</td>
#       <td id="T_7f8d5_row8_col2" class="data row8 col2" >0.360000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row9" class="row_heading level0 row9" >59</th>
#       <td id="T_7f8d5_row9_col0" class="data row9 col0" >computed tomography of chest, abdomen and pelvis (procedure)</td>
#       <td id="T_7f8d5_row9_col1" class="data row9 col1" >1203</td>
#       <td id="T_7f8d5_row9_col2" class="data row9 col2" >0.330000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row10" class="row_heading level0 row10" >41</th>
#       <td id="T_7f8d5_row10_col0" class="data row10 col0" >computed tomography of abdomen and pelvis (procedure)</td>
#       <td id="T_7f8d5_row10_col1" class="data row10 col1" >1144</td>
#       <td id="T_7f8d5_row10_col2" class="data row10 col2" >0.310000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row11" class="row_heading level0 row11" >172</th>
#       <td id="T_7f8d5_row11_col0" class="data row11 col0" >computed tomography of urinary tract (procedure)</td>
#       <td id="T_7f8d5_row11_col1" class="data row11 col1" >979</td>
#       <td id="T_7f8d5_row11_col2" class="data row11 col2" >0.270000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row12" class="row_heading level0 row12" >23</th>
#       <td id="T_7f8d5_row12_col0" class="data row12 col0" >computed tomography angiography of pulmonary artery (procedure)</td>
#       <td id="T_7f8d5_row12_col1" class="data row12 col1" >915</td>
#       <td id="T_7f8d5_row12_col2" class="data row12 col2" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row13" class="row_heading level0 row13" >174</th>
#       <td id="T_7f8d5_row13_col0" class="data row13 col0" >computed tomography of urinary tract with contrast (procedure)</td>
#       <td id="T_7f8d5_row13_col1" class="data row13 col1" >863</td>
#       <td id="T_7f8d5_row13_col2" class="data row13 col2" >0.240000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row14" class="row_heading level0 row14" >127</th>
#       <td id="T_7f8d5_row14_col0" class="data row14 col0" >computed tomography of neck, thorax, abdomen and pelvis with contrast (procedure)</td>
#       <td id="T_7f8d5_row14_col1" class="data row14 col1" >840</td>
#       <td id="T_7f8d5_row14_col2" class="data row14 col2" >0.230000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row15" class="row_heading level0 row15" >51</th>
#       <td id="T_7f8d5_row15_col0" class="data row15 col0" >computed tomography of aorta (procedure)</td>
#       <td id="T_7f8d5_row15_col1" class="data row15 col1" >775</td>
#       <td id="T_7f8d5_row15_col2" class="data row15 col2" >0.210000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row16" class="row_heading level0 row16" >19</th>
#       <td id="T_7f8d5_row16_col0" class="data row16 col0" >computed tomography angiography of intracranial artery (procedure)</td>
#       <td id="T_7f8d5_row16_col1" class="data row16 col1" >770</td>
#       <td id="T_7f8d5_row16_col2" class="data row16 col2" >0.210000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row17" class="row_heading level0 row17" >225</th>
#       <td id="T_7f8d5_row17_col0" class="data row17 col0" >virtual computed tomography colonoscopy (procedure)</td>
#       <td id="T_7f8d5_row17_col1" class="data row17 col1" >705</td>
#       <td id="T_7f8d5_row17_col2" class="data row17 col2" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row18" class="row_heading level0 row18" >163</th>
#       <td id="T_7f8d5_row18_col0" class="data row18 col0" >computed tomography of thorax and abdomen with contrast (procedure)</td>
#       <td id="T_7f8d5_row18_col1" class="data row18 col1" >684</td>
#       <td id="T_7f8d5_row18_col2" class="data row18 col2" >0.190000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row19" class="row_heading level0 row19" >134</th>
#       <td id="T_7f8d5_row19_col0" class="data row19 col0" >computed tomography of paranasal sinuses (procedure)</td>
#       <td id="T_7f8d5_row19_col1" class="data row19 col1" >437</td>
#       <td id="T_7f8d5_row19_col2" class="data row19 col2" >0.120000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row20" class="row_heading level0 row20" >136</th>
#       <td id="T_7f8d5_row20_col0" class="data row20 col0" >computed tomography of pelvis (procedure)</td>
#       <td id="T_7f8d5_row20_col1" class="data row20 col1" >377</td>
#       <td id="T_7f8d5_row20_col2" class="data row20 col2" >0.110000</td>
#     </tr>
#     <tr>
#       <th id="T_7f8d5_level0_row21" c
# <style type="text/css">
# </style>
# <table id="T_8dd9d">
#   <caption>Top 50 MRI (de-duplicated)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8dd9d_level0_col0" class="col_heading level0 col0" >proc_clean</th>
#       <th id="T_8dd9d_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_8dd9d_level0_col2" class="col_heading level0 col2" >% of Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8dd9d_level0_row0" class="row_heading level0 row0" >104</th>
#       <td id="T_8dd9d_row0_col0" class="data row0 col0" >magnetic resonance imaging of head (procedure)</td>
#       <td id="T_8dd9d_row0_col1" class="data row0 col1" >5331</td>
#       <td id="T_8dd9d_row0_col2" class="data row0 col2" >1.450000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row1" class="row_heading level0 row1" >156</th>
#       <td id="T_8dd9d_row1_col0" class="data row1 col0" >magnetic resonance imaging of lumbar and sacral spine (procedure)</td>
#       <td id="T_8dd9d_row1_col1" class="data row1 col1" >2993</td>
#       <td id="T_8dd9d_row1_col2" class="data row1 col2" >0.810000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row2" class="row_heading level0 row2" >107</th>
#       <td id="T_8dd9d_row2_col0" class="data row2 col0" >magnetic resonance imaging of head with contrast (procedure)</td>
#       <td id="T_8dd9d_row2_col1" class="data row2 col1" >1662</td>
#       <td id="T_8dd9d_row2_col2" class="data row2 col2" >0.450000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row3" class="row_heading level0 row3" >78</th>
#       <td id="T_8dd9d_row3_col0" class="data row3 col0" >magnetic resonance imaging of cervical spine (procedure)</td>
#       <td id="T_8dd9d_row3_col1" class="data row3 col1" >1488</td>
#       <td id="T_8dd9d_row3_col2" class="data row3 col2" >0.410000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row4" class="row_heading level0 row4" >230</th>
#       <td id="T_8dd9d_row4_col0" class="data row4 col0" >magnetic resonance imaging of spine (procedure)</td>
#       <td id="T_8dd9d_row4_col1" class="data row4 col1" >1346</td>
#       <td id="T_8dd9d_row4_col2" class="data row4 col2" >0.370000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row5" class="row_heading level0 row5" >114</th>
#       <td id="T_8dd9d_row5_col0" class="data row5 col0" >magnetic resonance imaging of internal auditory meatus (procedure)</td>
#       <td id="T_8dd9d_row5_col1" class="data row5 col1" >1094</td>
#       <td id="T_8dd9d_row5_col2" class="data row5 col2" >0.300000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row6" class="row_heading level0 row6" >19</th>
#       <td id="T_8dd9d_row6_col0" class="data row6 col0" >magnetic resonance cholangiopancreatography (procedure)</td>
#       <td id="T_8dd9d_row6_col1" class="data row6 col1" >894</td>
#       <td id="T_8dd9d_row6_col2" class="data row6 col2" >0.240000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row7" class="row_heading level0 row7" >206</th>
#       <td id="T_8dd9d_row7_col0" class="data row7 col0" >magnetic resonance imaging of right knee (procedure)</td>
#       <td id="T_8dd9d_row7_col1" class="data row7 col1" >782</td>
#       <td id="T_8dd9d_row7_col2" class="data row7 col2" >0.210000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row8" class="row_heading level0 row8" >136</th>
#       <td id="T_8dd9d_row8_col0" class="data row8 col0" >magnetic resonance imaging of left knee (procedure)</td>
#       <td id="T_8dd9d_row8_col1" class="data row8 col1" >743</td>
#       <td id="T_8dd9d_row8_col2" class="data row8 col2" >0.200000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row9" class="row_heading level0 row9" >187</th>
#       <td id="T_8dd9d_row9_col0" class="data row9 col0" >magnetic resonance imaging of prostate (procedure)</td>
#       <td id="T_8dd9d_row9_col1" class="data row9 col1" >727</td>
#       <td id="T_8dd9d_row9_col2" class="data row9 col2" >0.190000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row10" class="row_heading level0 row10" >177</th>
#       <td id="T_8dd9d_row10_col0" class="data row10 col0" >magnetic resonance imaging of pelvis (procedure)</td>
#       <td id="T_8dd9d_row10_col1" class="data row10 col1" >691</td>
#       <td id="T_8dd9d_row10_col2" class="data row10 col2" >0.190000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row11" class="row_heading level0 row11" >240</th>
#       <td id="T_8dd9d_row11_col0" class="data row11 col0" >magnetic resonance imaging of thoracic spine (procedure)</td>
#       <td id="T_8dd9d_row11_col1" class="data row11 col1" >567</td>
#       <td id="T_8dd9d_row11_col2" class="data row11 col2" >0.150000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row12" class="row_heading level0 row12" >158</th>
#       <td id="T_8dd9d_row12_col0" class="data row12 col0" >magnetic resonance imaging of lumbar spine (procedure)</td>
#       <td id="T_8dd9d_row12_col1" class="data row12 col1" >392</td>
#       <td id="T_8dd9d_row12_col2" class="data row12 col2" >0.110000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row13" class="row_heading level0 row13" >165</th>
#       <td id="T_8dd9d_row13_col0" class="data row13 col0" >magnetic resonance imaging of neck (procedure)</td>
#       <td id="T_8dd9d_row13_col1" class="data row13 col1" >373</td>
#       <td id="T_8dd9d_row13_col2" class="data row13 col2" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row14" class="row_heading level0 row14" >180</th>
#       <td id="T_8dd9d_row14_col0" class="data row14 col0" >magnetic resonance imaging of pelvis with contrast (procedure)</td>
#       <td id="T_8dd9d_row14_col1" class="data row14 col1" >358</td>
#       <td id="T_8dd9d_row14_col2" class="data row14 col2" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row15" class="row_heading level0 row15" >167</th>
#       <td id="T_8dd9d_row15_col0" class="data row15 col0" >magnetic resonance imaging of neck with contrast (procedure)</td>
#       <td id="T_8dd9d_row15_col1" class="data row15 col1" >330</td>
#       <td id="T_8dd9d_row15_col2" class="data row15 col2" >0.090000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row16" class="row_heading level0 row16" >189</th>
#       <td id="T_8dd9d_row16_col0" class="data row16 col0" >magnetic resonance imaging of rectum (procedure)</td>
#       <td id="T_8dd9d_row16_col1" class="data row16 col1" >327</td>
#       <td id="T_8dd9d_row16_col2" class="data row16 col2" >0.090000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row17" class="row_heading level0 row17" >8</th>
#       <td id="T_8dd9d_row17_col0" class="data row17 col0" >gynaecological magnetic resonance imaging of pelvis (procedure)</td>
#       <td id="T_8dd9d_row17_col1" class="data row17 col1" >318</td>
#       <td id="T_8dd9d_row17_col2" class="data row17 col2" >0.080000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row18" class="row_heading level0 row18" >219</th>
#       <td id="T_8dd9d_row18_col0" class="data row18 col0" >magnetic resonance imaging of sacroiliac joints (procedure)</td>
#       <td id="T_8dd9d_row18_col1" class="data row18 col1" >314</td>
#       <td id="T_8dd9d_row18_col2" class="data row18 col2" >0.090000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row19" class="row_heading level0 row19" >152</th>
#       <td id="T_8dd9d_row19_col0" class="data row19 col0" >magnetic resonance imaging of liver with contrast (procedure)</td>
#       <td id="T_8dd9d_row19_col1" class="data row19 col1" >299</td>
#       <td id="T_8dd9d_row19_col2" class="data row19 col2" >0.080000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row20" class="row_heading level0 row20" >110</th>
#       <td id="T_8dd9d_row20_col0" class="data row20 col0" >magnetic resonance imaging of heart for assessment of myocardial viability (procedure)</td>
#       <td id="T_8dd9d_row20_col1" class="data row20 col1" >287</td>
#       <td id="T_8dd9d_row20_col2" class="data row20 col2" >0.070000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd9d_level0_row21" class="row_head
